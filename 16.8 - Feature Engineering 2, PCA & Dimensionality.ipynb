# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

warnings.filterwarnings('ignore')

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'useducation'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

usedu = pd.read_sql_query('select * from useducation',con=engine)

engine.dispose()
print(usedu.columns)
usedu.sort_values('STATE').head()
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'GRADES_PK_G', 'GRADES_KG_G',
#        'GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G',
#        'GRADES_9_12_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')
#        PRIMARY_KEY    STATE  YEAR        ENROLL  TOTAL_REVENUE  \
# 0     1992_ALABAMA  ALABAMA  1992           nan 2678885.000000
# 104   1994_ALABAMA  ALABAMA  1994 730004.000000 2970223.000000
# 157   1995_ALABAMA  ALABAMA  1995 727480.000000 3367437.000000
# 1250  2016_ALABAMA  ALABAMA  2016 734652.000000 7498567.000000
# 209   1996_ALABAMA  ALABAMA  1996 735912.000000 3365113.000000
#
# ...

# %%
usedu.sort_values(by=['STATE', 'YEAR'])
usedu.at[0, 'ENROLL'] = 730004.0
usedu.at[0, 'AVG_READING_8_SCORE'] = 260.276441
usedu.drop(usedu[usedu['YEAR'] == 2016].index, inplace=True)
usedu.drop(usedu[usedu['YEAR'] == 2017].index, inplace=True)
usedu.interpolate(method ='linear', limit=None,inplace=True, limit_direction='both', limit_area=None, downcast=None)

pd.set_option('float_format', '{:f}'.format)
print(usedu.columns)
usedu.tail(20)
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'GRADES_PK_G', 'GRADES_KG_G',
#        'GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G',
#        'GRADES_9_12_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')
#                         PRIMARY_KEY                     STATE  YEAR  \
# 1427            1996_AMERICAN_SAMOA            AMERICAN_SAMOA  1996
# 1428                      1996_GUAM                      GUAM  1996
# 1429  1996_COMMONWEALTH_OF_MARIANAS  COMMONWEALTH_OF_MARIANAS  1996
# 1430               1996_PUERTO_RICO               PUERTO_RICO  1996
# 1431            1996_VIRGIN_ISLANDS            VIRGIN_ISLANDS  1996
# ...

# %% [markdown]
# 1. Create a new score variable from the weighted averages of all score variables in the datasets. Notice that the number of students in the 4th grade isn't the same as the number of students in the 8th grade. So, you should appropriately weigh the scores!

# %%
def weighted_average(df):
    df['WEIGHTED_AVERAGE'] = ''
    for i, row in df.iterrows():
        total_students = df.iloc[i]['GRADES_4_G'] + df.iloc[i]['GRADES_8_G']
        grade_4_weight = df.iloc[i]['GRADES_4_G'] / total_students
        grade_8_weight = df.iloc[i]['GRADES_8_G'] / total_students
        grade_4_average = ((df.iloc[i]['AVG_MATH_4_SCORE'] + df.iloc[i]['AVG_READING_4_SCORE']) / 2)
        grade_8_average = ((df.iloc[i]['AVG_MATH_8_SCORE'] + df.iloc[i]['AVG_READING_8_SCORE']) / 2)
        weighted_average = grade_4_average * grade_4_weight + grade_8_average * grade_8_weight
        df.iloc[i, df.columns.get_loc('WEIGHTED_AVERAGE')] = weighted_average
    
wa_usedu = weighted_average(usedu)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-ea33ee2431e6> in <module>
#      10         df.iloc[i, df.columns.get_loc('WEIGHTED_AVERAGE')] = weighted_average
#      11
# ---> 12 wa_usedu = weighted_average(usedu)
#
# <ipython-input-47-ea33ee2431e6> in weighted_average(df)
#       2     df['WEIGHTED_AVERAGE'] = ''
#       3     for i, row in df.iterrows():
# ----> 4         total_students = df.iloc[i]['GRADES_4_G'] + df.iloc[i]['GRADES_8_G']
#       5         grade_4_weight = df.iloc[i]['GRADES_4_G'] / total_students
#       6         grade_8_weight = df.iloc[i]['GRADES_8_G'] / total_students
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
# ...

# %%
usedu.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR        ENROLL   TOTAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992 730004.000000  2678885.000000
# 1      1992_ALASKA      ALASKA  1992 712218.083333  1049591.000000
# 2     1992_ARIZONA     ARIZONA  1992 694432.166667  3258079.000000
# 3    1992_ARKANSAS    ARKANSAS  1992 676646.250000  1711959.000000
# 4  1992_CALIFORNIA  CALIFORNIA  1992 658860.333333 26260025.000000
#
#    FEDERAL_REVENUE   STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0    304177.000000  1659028.000000  715680.000000     2653798.000000
# 1    106780.000000   720711.000000  222100.000000      972488.000000
# 2    297888.000000  1369815.000000 1590376.000000     3401580.000000
# 3    178571.000000   958785.000000  574603.000000     1743022.000000
# 4   2072470.000000 16546514.000000 7641041.000000    27138832.000000
#
#    INSTRUCTION_EXPENDITURE  ...    GRADES_8_G   GRADES_12_G   GRADES_1_8_G  \
# ...

# %%
usedu.corr()
# Out:
#                                  YEAR    ENROLL  TOTAL_REVENUE  \
# YEAR                         1.000000  0.056180       0.215559
# ENROLL                       0.056180  1.000000       0.916052
# TOTAL_REVENUE                0.215559  0.916052       1.000000
# FEDERAL_REVENUE              0.260676  0.891161       0.930947
# STATE_REVENUE                0.199917  0.916114       0.973572
# LOCAL_REVENUE                0.205620  0.852652       0.966321
# TOTAL_EXPENDITURE            0.209783  0.916195       0.999102
# INSTRUCTION_EXPENDITURE      0.207587  0.885687       0.991029
# SUPPORT_SERVICES_EXPENDITURE 0.225614  0.918381       0.995230
# OTHER_EXPENDITURE            0.207273  0.955578       0.944078
# CAPITAL_OUTLAY_EXPENDITURE   0.155122  0.909712       0.926647
# GRADES_PK_G                  0.157044  0.783018       0.725603
# GRADES_KG_G                  0.022511  0.973525       0.895646
# GRADES_4_G                   0.015052  0.975569       0.898411
# ...

# %% [markdown]
# 2. What are the correlations between this newly created score variable and the expenditure types? Which 1 of the expenditure types is more correlated than the others?

# %%
usedu.corr()
# Out:
#                                  YEAR    ENROLL  TOTAL_REVENUE  \
# YEAR                         1.000000  0.056180       0.215559
# ENROLL                       0.056180  1.000000       0.916052
# TOTAL_REVENUE                0.215559  0.916052       1.000000
# FEDERAL_REVENUE              0.260676  0.891161       0.930947
# STATE_REVENUE                0.199917  0.916114       0.973572
# LOCAL_REVENUE                0.205620  0.852652       0.966321
# TOTAL_EXPENDITURE            0.209783  0.916195       0.999102
# INSTRUCTION_EXPENDITURE      0.207587  0.885687       0.991029
# SUPPORT_SERVICES_EXPENDITURE 0.225614  0.918381       0.995230
# OTHER_EXPENDITURE            0.207273  0.955578       0.944078
# CAPITAL_OUTLAY_EXPENDITURE   0.155122  0.909712       0.926647
# GRADES_PK_G                  0.157044  0.783018       0.725603
# GRADES_KG_G                  0.022511  0.973525       0.895646
# GRADES_4_G                   0.015052  0.975569       0.898411
# ...

# %% [markdown]
# Now, apply PCA to the 4 expenditure types. How much of the total variance is explained by the 1st component?
#
#
# What is the correlation between the overall score variable and the 1st principal component?
#
#
# If you were to choose the best variables for your model, would you prefer using the 1st principal component instead of the expenditure variables? Why?
